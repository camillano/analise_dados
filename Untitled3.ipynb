# %% [markdown]
# <a href="https://colab.research.google.com/github/camillano/analise_dados/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configurar usuário Git
# !git config --global user.name "Camilla"
# !git config --global user.email "camilla.direito@gmail.com"

# Verificar configuração
# !git config --global --list

from google.colab import userdata
import os

from google.colab import userdata

token = userdata.get('GITHUB_TOKEN')

# !git clone https://github.com/cfneves/turma-visualizacao-de-dados.git
# %cd turma-visualizacao-de-dados
# !ls

# %cd /content
# !ls

# !rm -rf turma-visualizacao-de-dados

# !git clone https://github.com/cfneves/turma-visualizacao-de-dados.git
# %cd turma-visualizacao-de-dados
# !ls

# %cd alunos
# !ls

# !mkdir camilla
# %cd camilla

# !touch atividade1.ipynb

# !git add .
# !git commit -m "Adicionando atividade da Camilla"

# %cd alunos
# !ls

from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')

# !git push https://{token}@github.com/cfneves/turma-visualizacao-de-dados.git
# Out:
# user.name=Camilla
# user.email=camilla.direito@gmail.com
# Cloning into 'turma-visualizacao-de-dados'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 237 (delta 102), reused 82 (delta 65), pack-reused 98 (from 1)
# Receiving objects: 100% (237/237), 43.83 KiB | 1.02 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# /content/turma-visualizacao-de-dados/alunos/camilla/turma-visualizacao-de-dados
# alunos	CONTRIBUTING.md  exercicios  PULL_REQUEST_TEMPLATE.md
# aulas	datasets	 projetos    README.md
# /content
# sample_data  turma-visualizacao-de-dados
# Cloning into 'turma-visualizacao-de-dados'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 237 (delta 102), reused 83 (delta 65), pack-reused 98 (from 1)
# ...
