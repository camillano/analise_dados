# %% [markdown]
# <a href="https://colab.research.google.com/github/camillano/analise_dados/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configurar usuário Git
# !git config --global user.name "Camilla"
# !git config --global user.email "camilla.direito@gmail.com"

# Verificar configuração
# !git config --global --list

from google.colab import userdata
import os

from google.colab import userdata

token = userdata.get('GITHUB_TOKEN')


# %cd /content/turma-visualizacao-de-dados/alunos
# !ls


# !mkdir camilla
# %cd camilla

# !pwd
# !ls

# %cd /content/turma-visualizacao-de-dados/alunos
# !ls

# %cd /content/turma-visualizacao-de-dados/alunos/camilla
# !pwd

atividade1.ipynb

# !ls
