# %% [markdown]
# <a href="https://colab.research.google.com/github/camillano/analise_dados/blob/main/atividade1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configurar usuário Git
# !git config --global user.name "Camilla"
# !git config --global user.email "camilla.direito@gmail.com"

# Verificar configuração
# !git config --global --list

from google.colab import userdata
import os

from google.colab import userdata

token = userdata.get('GITHUB_TOKEN')


# %cd /content/turma-visualizacao-de-dados


# !git pull origin master --rebase

# !mkdir camilla
# %cd camilla

# !pwd
# !ls

# %cd /content/turma-visualizacao-de-dados/alunos
# !ls

# %cd /content/turma-visualizacao-de-dados/alunos/camilla
# !pwd

# !pwd
# !ls

# !git add .
# !git commit -m "Atividade Camilla"


from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')

# !git push https://{token}@github.com/cfneves/turma-visualizacao-de-dados.git

# !ls


# %cd /content
# !rm -rf turma-visualizacao-de-dados


# !git clone https://github.com/cfneves/turma-visualizacao-de-dados.git
# %cd turma-visualizacao-de-dados
# !ls


# %cd alunos
# !ls

# !mkdir -p camilla
# %cd camilla

# !pwd
# !ls
